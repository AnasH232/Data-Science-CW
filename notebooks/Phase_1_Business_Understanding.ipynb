# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
# TODO: Define business objectives here.

business_objectives = {
    "background": "Airlines and airports face significant operational and financial challenges due to flight delays. Delays impact customer satisfaction, increase operational costs, and disrupt scheduling systems. This project aims to leverage historical flight data and external factors to better understand and predict delays.",
    
    "primary_objective": "Develop a predictive model to estimate flight delays before departure to support proactive decision-making.",
    
    "business_success_criteria": [
        "Reduce unexpected flight delays through better prediction",
        "Improve airline operational efficiency and scheduling",
        "Enhance passenger satisfaction by providing accurate delay information",
        "Enable data-driven decision making for airlines and airports"
    ]
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> BACKGROUND:
#    Airlines and airports face significant operational and financial challenges due to flight delays. Delays impact customer satisfaction, increase operational costs, and disrupt scheduling systems. This project aims to leverage historical flight data and external factors to better understand and predict delays.
#
# >> PRIMARY OBJECTIVE:
#    Develop a predictive model to estimate flight delays before departure to support proactive decision-making.
#
# >> BUSINESS SUCCESS CRITERIA:
#    - Reduce unexpected flight delays through better prediction
#    - Improve airline operational efficiency and scheduling
#    - Enhance passenger satisfaction by providing accurate delay information
#    - Enable data-driven decision making for airlines and airports

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
# TODO: Assess the current situation here.

situation_assessment = {
    "resources": {
        "data": [
            "Primary dataset: 2015 Flight Delays and Cancellations (Kaggle)",
            "Supplementary dataset: Weather data scraped from online sources"
        ],
        "tools": [
            "Python (pandas, numpy)",
            "Data visualisation (matplotlib, seaborn)",
            "Machine learning (scikit-learn)",
            "Web scraping (BeautifulSoup, Selenium)",
            "Version control (GitHub)"
        ],
        "hardware": [
            "Local machine (limited computational power)"
        ]
    },
    
    "requirements": [
        "Follow CRISP-DM lifecycle",
        "Implement web scraping and merge with primary dataset",
        "Perform rigorous data audit and cleaning",
        "Build a machine learning pipeline using sklearn.pipeline",
        "Ensure reproducibility via structured GitHub repository"
    ],
    
    "assumptions": [
        "Historical flight data from 2015 is representative of general delay patterns",
        "Weather conditions significantly influence flight delays",
        "Relationships in historical data can be learned by machine learning models"
    ],
    
    "constraints": [
        "Limited processing power restricts use of very large datasets or complex models",
        "Time constraints due to coursework deadline",
        "Availability and reliability of scraped data sources"
    ],
    
    "risks": [
        "Missing or inconsistent values in the dataset",
        "Difficulty aligning scraped weather data with flight records",
        "Potential overfitting due to high dimensionality",
        "Scraping limitations such as blocked requests or incomplete data"
    ]
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "data": [
#       "Primary dataset: 2015 Flight Delays and Cancellations (Kaggle)",
#       "Supplementary dataset: Weather data scraped from online sources"
#     ],
#     "tools": [
#       "Python (pandas, numpy)",
#       "Data visualisation (matplotlib, seaborn)",
#       "Machine learning (scikit-learn)",
#       "Web scraping (BeautifulSoup, Selenium)",
#       "Version control (GitHub)"
#     ],
#     "hardware": [
#       "Local machine (limited computational power)"
#     ]
#   },
#   "requirements": [
#     "Follow CRISP-DM lifecycle",
#     "Implement web scraping and merge with primary dataset",
#     "Perform rigorous data audit and cleaning",
#     "Build a machine learning pipeline using sklearn.pipeline",
#     "Ensure reproducibility via structured GitHub repository"
#   ],
#   "assumptions": [
#     "Historical flight data from 2015 is representative of general delay patterns",
#     "Weather conditions significantly influence flight delays",
#     "Relationships in historical data can be learned by machine learning models"
#   ],
#   "constraints": [
#     "Limited processing power restricts use of very large datasets or complex models",
#     "Time constraints due to coursework deadline",
#     "Availability and reliability of scraped data sources"
#   ],
#   "risks": [
#     "Missing or inconsistent values in the dataset",
#     "Difficulty aligning scraped weather data with flight records",
#     "Potential overfitting due to high dimensionality",
#     "Scraping limitations such as blocked requests or incomplete data"
#   ]
# }

# %%
# Optional: Add any further notes or elaboration on the situation assessment

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
# TODO: Define data mining goals here.

data_mining_goals = {
    "problem_type": "Regression",
    
    "target_variable": "ARRIVAL_DELAY",
    
    "input_features": [
        "DEPARTURE_TIME",
        "SCHEDULED_DEPARTURE",
        "AIRLINE",
        "ORIGIN_AIRPORT",
        "DESTINATION_AIRPORT",
        "DISTANCE",
        "DAY_OF_WEEK",
        "WEATHER_FEATURES (scraped)"
    ],
    
    "technical_goals": [
        "Identify key variables that influence flight delays",
        "Build a predictive model for arrival delay",
        "Evaluate multiple models and select the best performing one",
        "Incorporate external data (weather) to improve prediction accuracy"
    ],
    
    "success_metrics": [
        "Low RMSE on test dataset",
        "Consistent performance across cross-validation folds",
        "No data leakage in preprocessing steps",
        "Improved performance after adding scraped data"
    ]
}

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")
# Out:
# ============================================================
# BUSINESS TO DATA MINING GOAL MAPPING
# ============================================================
#
# Business Objective : Develop a predictive model to estimate flight delays before departure to support proactive decision-making.
# Problem Type       : Regression
# Target Variable    : ARRIVAL_DELAY
#
# Technical Goals:
#   - Identify key variables that influence flight delays
#   - Build a predictive model for arrival delay
#   - Evaluate multiple models and select the best performing one
#   - Incorporate external data (weather) to improve prediction accuracy
#
# Success Metrics:
#   - Low RMSE on test dataset
#   - Consistent performance across cross-validation folds
#   - No data leakage in preprocessing steps
#   - Improved performance after adding scraped data

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
# TODO: Produce your project plan here.

project_plan = {
    "tools": [
        "pandas",
        "numpy",
        "matplotlib",
        "seaborn",
        "scikit-learn",
        "BeautifulSoup",
        "Selenium",
        "joblib",
        "Jupyter Notebook",
        "GitHub"
    ],
    "techniques": [
        "Exploratory Data Analysis",
        "Data Merging",
        "Web Scraping",
        "Train-Test Split",
        "Cross-Validation",
        "Hyperparameter Tuning",
        "Linear Regression",
        "Pipeline Modelling"
    ],
    "timeline": [
        {"phase": "Business Understanding", "duration": "Week 1", "status": "Completed"},
        {"phase": "Data Understanding", "duration": "Week 1-2", "status": "Completed"},
        {"phase": "Data Preparation", "duration": "Week 2-4", "status": "Not Started"},
        {"phase": "Modelling", "duration": "Week 4-5", "status": "Not Started"},
        {"phase": "Evaluation", "duration": "Week 5-6", "status": "Not Started"},
        {"phase": "Deployment", "duration": "Week 6", "status": "Not Started"}
    ],
    "dependencies": [
        "The 2015 Kaggle Flight Delays and Cancellations dataset must be downloaded and accessible before Data Understanding can begin.",
        "Supplementary weather data must be scraped successfully before dataset merging and feature augmentation can be completed.",
        "Data cleaning and preprocessing must be completed before modelling can begin.",
        "Feature engineering and dataset splitting must be completed before cross-validation and hyperparameter tuning.",
    ],
    "tool_justification": (
        "Pandas and NumPy will be used for data manipulation, cleaning, and transformation."
        "Matplotlib and Seaborn will be used for visualisation to explore delay distributions, correlations, and feature patterns. "
        "Scikit-learn will be used to build the machine learning workflow"
        "BeautifulSoup and Selenium will be used for scraping supplementary weather-related data, which will be merged with the main dataset to improve the "
        "predictive power of the model. "
    )
}

# %%
# Display the project plan
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for phase in project_plan['timeline']:
        print(f"  [{phase.get('status', 'N/A'):^12}] {phase['phase']:<25} | {phase['duration']}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")
# Out:
# ============================================================
# PROJECT PLAN
# ============================================================
#
# Tools: pandas, numpy, matplotlib, seaborn, scikit-learn, BeautifulSoup, Selenium, joblib, Jupyter Notebook, GitHub
# Techniques: Exploratory Data Analysis, Data Merging, Web Scraping, Train-Test Split, Cross-Validation, Hyperparameter Tuning, Linear Regression, Pipeline Modelling
#
# Timeline:
#   [ Completed  ] Business Understanding    | Week 1
#   [ Completed  ] Data Understanding        | Week 1-2
#   [Not Started ] Data Preparation          | Week 2-4
#   [Not Started ] Modelling                 | Week 4-5
#   [Not Started ] Evaluation                | Week 5-6
#   [Not Started ] Deployment                | Week 6
#
# Dependencies:
#   - The 2015 Kaggle Flight Delays and Cancellations dataset must be downloaded and accessible before Data Understanding can begin.
#   - Supplementary weather data must be scraped successfully before dataset merging and feature augmentation can be completed.
#   - Data cleaning and preprocessing must be completed before modelling can begin.
#   - Feature engineering and dataset splitting must be completed before cross-validation and hyperparameter tuning.
#
# Tool Justification: Pandas and NumPy will be used for data manipulation, cleaning, and transformation.Matplotlib and Seaborn will be used for visualisation to explore delay distributions, correlations, and feature patterns. Scikit-learn will be used to build the machine learning workflowBeautifulSoup and Selenium will be used for scraping supplementary weather-related data, which will be merged with the main dataset to improve the predictive power of the model.

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ============================================================
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ============================================================
#
# Primary Objective  : Develop a predictive model to estimate flight delays before departure to support proactive decision-making.
# Problem Type       : Regression
# Target Variable    : ARRIVAL_DELAY
# Tools Planned      : pandas, numpy, matplotlib, seaborn, scikit-learn, BeautifulSoup, Selenium, joblib, Jupyter Notebook, GitHub
# Techniques Planned : Exploratory Data Analysis, Data Merging, Web Scraping, Train-Test Split, Cross-Validation, Hyperparameter Tuning, Linear Regression, Pipeline Modelling
